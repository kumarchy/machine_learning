# %%
import pandas as pd
import numpy as np

# %%
laptopData=pd.read_csv('laptopData.csv')
laptopData
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
laptopData.drop(columns=['Unnamed: 0'],inplace=True)

# %%
laptopData.shape
# Out:
# (1303, 11)

# %%
laptopData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 1303 entries, 0 to 1302
#
# Data columns (total 11 columns):
#
#  #   Column            Non-Null Count  Dtype
#
# ---  ------            --------------  -----
#
#  0   Company           1273 non-null   object
#
#  1   TypeName          1273 non-null   object
#
#  2   Inches            1273 non-null   object
#
#  3   ScreenResolution  1273 non-null   object
#
#  4   Cpu               1273 non-null   object
#
#  5   Ram               1273 non-null   object
#
#  6   Memory            1273 non-null   object
#
#  7   Gpu               1273 non-null   object
#
#  8   OpSys             1273 non-null   object
#
#  9   Weight            1273 non-null   object
#
#  10  Price             1273 non-null   float64
#
# dtypes: float64(1), object(10)
#
# memory usage: 112.1+ KB

# %%
laptopData
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook     14
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
laptopData.describe()
# Out:
#                Price
# count    1273.000000
# mean    59955.814073
# std     37332.251005
# min      9270.720000
# 25%     31914.720000
# 50%     52161.120000
# 75%     79333.387200
# max    324954.720000

# %%
laptopData['Company'].describe()
# Out:
# count       1273
# unique        19
# top       Lenovo
# freq         290
# Name: Company, dtype: object

# %%
laptop=laptopData[laptopData['Company']=='LG']

# %%
laptop.duplicated().sum()
# Out:
# 0

# %%
laptopData['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', nan, 'Chuwi',
#        'MSI', 'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
laptopData['Price'].describe()
# Out:
# count      1273.000000
# mean      59955.814073
# std       37332.251005
# min        9270.720000
# 25%       31914.720000
# 50%       52161.120000
# 75%       79333.387200
# max      324954.720000
# Name: Price, dtype: float64

# %%
laptopData[laptopData['Price']==9270.720000]
# Out:
#      Company TypeName Inches ScreenResolution  \
# 1215    Acer  Netbook   11.6         1366x768
#
#                                        Cpu  Ram    Memory                Gpu  \
# 1215  Intel Celeron Dual Core 3205U 1.5GHz  2GB  32GB SSD  Intel HD Graphics
#
#           OpSys Weight    Price
# 1215  Chrome OS  1.3kg  9270.72

# %%
laptopData[laptopData['Memory']=='128GB Flash Storage']
# Out:
#     Company   TypeName Inches ScreenResolution  \
# 1     Apple  Ultrabook   13.3         1440x900
# 26    Apple  Ultrabook   13.3         1440x900
# 319    Acer   Notebook   11.6         1366x768
# 609    Acer   Notebook     14         1366x768
#
#                                       Cpu  Ram               Memory  \
# 1                    Intel Core i5 1.8GHz  8GB  128GB Flash Storage
# 26                   Intel Core i5 1.6GHz  8GB  128GB Flash Storage
# 319  Intel Pentium Quad Core N3710 1.6GHz  4GB  128GB Flash Storage
# 609  Intel Pentium Quad Core N3710 1.6GHz  4GB  128GB Flash Storage
#
#                         Gpu       OpSys  Weight       Price
# 1    Intel HD Graphics 6000       macOS  1.34kg  47895.5232
# 26   Intel HD Graphics 6000    Mac OS X  1.35kg  58554.7200
# 319   Intel HD Graphics 405  Windows 10   1.4kg  25840.8000
# 609   Intel HD Graphics 405  Windows 10   1.6kg  18594.7200

# %% [markdown]
# ## Dirty data
# #### table has null value(c)
# #### inches column should be float(a)
# #### screenresolution column has both letter and number combination(v)
# #### opsys has no os in some rows(v)
# #### price column is in float value(a)
# #### table has duplicated value(a)
# #### lenovo has 8 duplicated rows(a)
# #### HP has 6 duplicate rows(a)
# #### Asus has 7 duplicated rows(a)
# #### Acer has 2 duplicate rows(a)
# #### Dell has 6 duplicated rows(a)
# #### attached kg should be removed from weight column(a)
# #### price column should be in integer value(v)
# #### in opsys column Mac OS X is not valid(v)

# %%
laptopData.describe()
# Out:
#                Price
# count    1273.000000
# mean    59955.814073
# std     37332.251005
# min      9270.720000
# 25%     31914.720000
# 50%     52161.120000
# 75%     79333.387200
# max    324954.720000

# %%
laptopData['Cpu']
# Out:
# 0                       Intel Core i5 2.3GHz
# 1                       Intel Core i5 1.8GHz
# 2                 Intel Core i5 7200U 2.5GHz
# 3                       Intel Core i7 2.7GHz
# 4                       Intel Core i5 3.1GHz
#                         ...
# 1298              Intel Core i7 6500U 2.5GHz
# 1299              Intel Core i7 6500U 2.5GHz
# 1300    Intel Celeron Dual Core N3050 1.6GHz
# 1301              Intel Core i7 6500U 2.5GHz
# 1302    Intel Celeron Dual Core N3050 1.6GHz
# Name: Cpu, Length: 1303, dtype: object

# %%
laptopData.sort_values('Price',ascending=False,na_position='first')
# Out:
#      Company  TypeName Inches   ScreenResolution  \
# 20       NaN       NaN    NaN                NaN
# 46       NaN       NaN    NaN                NaN
# 50       NaN       NaN    NaN                NaN
# 115      NaN       NaN    NaN                NaN
# 125      NaN       NaN    NaN                NaN
# ...      ...       ...    ...                ...
# 791     Vero  Notebook     14          1920x1080
# 31      Asus  Notebook     14           1366x768
# 290     Acer  Notebook   15.6           1366x768
# 1120    Vero  Notebook   13.3  Full HD 1920x1080
# 1215    Acer   Netbook   11.6           1366x768
#
#                                        Cpu  Ram              Memory  \
# 20                                     NaN  NaN                 NaN
# 46                                     NaN  NaN                 NaN
# 50                                     NaN  NaN                 NaN
# 115                                    NaN  NaN                 NaN
# ...

# %% [markdown]
# ## 30-null value is found

# %%
with pd.ExcelWriter('laptop.xlsx') as writer:
     laptopData.to_excel(writer,sheet_name='laptop_details')

# %%
laptop_det=laptopData.sort_values('Price',ascending=False,na_position='first').dropna()
laptop_det.head()
# Out:
#      Company     TypeName Inches                     ScreenResolution  \
# 196    Razer       Gaming   17.3  4K Ultra HD / Touchscreen 3840x2160
# 830    Razer       Gaming   17.3  4K Ultra HD / Touchscreen 3840x2160
# 610   Lenovo     Notebook   15.6      IPS Panel 4K Ultra HD 3840x2160
# 749       HP  Workstation   17.3          IPS Panel Full HD 1920x1080
# 1066    Asus       Gaming   17.3          IPS Panel Full HD 1920x1080
#
#                                 Cpu   Ram     Memory                      Gpu  \
# 196     Intel Core i7 7820HK 2.9GHz  32GB    1TB SSD  Nvidia GeForce GTX 1080
# 830     Intel Core i7 7820HK 2.9GHz  32GB  512GB SSD  Nvidia GeForce GTX 1080
# 610   Intel Xeon E3-1535M v6 3.1GHz  32GB    1TB SSD     Nvidia Quadro M2200M
# 749   Intel Xeon E3-1535M v5 2.9GHz  16GB  256GB SSD     Nvidia Quadro M2000M
# 1066    Intel Core i7 6820HK 2.7GHz  64GB    1TB SSD  Nvidia GeForce GTX 980
#
#            OpSys  Weight      Price
# 196   Windows 10  3.49kg  324954.72
# ...

# %%
laptop_det.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# Int64Index: 1273 entries, 196 to 1215
#
# Data columns (total 11 columns):
#
#  #   Column            Non-Null Count  Dtype
#
# ---  ------            --------------  -----
#
#  0   Company           1273 non-null   object
#
#  1   TypeName          1273 non-null   object
#
#  2   Inches            1273 non-null   object
#
#  3   ScreenResolution  1273 non-null   object
#
#  4   Cpu               1273 non-null   object
#
#  5   Ram               1273 non-null   object
#
#  6   Memory            1273 non-null   object
#
#  7   Gpu               1273 non-null   object
#
#  8   OpSys             1273 non-null   object
#
#  9   Weight            1273 non-null   object
#
#  10  Price             1273 non-null   float64
#
# dtypes: float64(1), object(10)
#
# memory usage: 119.3+ KB

# %%
laptop_det['OpSys'].sample(10)
# Out:
# 291       Windows 10
# 266       Windows 10
# 355       Windows 10
# 670     Windows 10 S
# 423            Linux
# 805       Windows 10
# 580       Windows 10
# 993       Windows 10
# 1302      Windows 10
# 1057      Windows 10
# Name: OpSys, dtype: object

# %%
laptop_det[laptop_det['OpSys']=='No OS'].head()
# Out:
#     Company  TypeName Inches             ScreenResolution  \
# 514  Xiaomi  Notebook   15.6  IPS Panel Full HD 1920x1080
# 205  Lenovo    Gaming   15.6            Full HD 1920x1080
# 184  Xiaomi  Notebook   15.6  IPS Panel Full HD 1920x1080
# 643    Asus    Gaming   15.6  IPS Panel Full HD 1920x1080
# 509  Lenovo    Gaming   15.6  IPS Panel Full HD 1920x1080
#
#                              Cpu   Ram                Memory  \
# 514   Intel Core i7 8550U 1.8GHz  16GB             256GB SSD
# 205  Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 184   Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
# 643  Intel Core i7 7700HQ 2.8GHz   8GB               1TB HDD
# 509  Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
#
#                             Gpu  OpSys  Weight      Price
# 514        Nvidia GeForce MX150  No OS  1.95kg  74589.336
# 205     Nvidia GeForce GTX 1060  No OS   2.4kg  74485.440
# 184        Nvidia GeForce MX150  No OS  1.95kg  63882.720
# ...

# %%
laptop_det.index.name = 'index'
laptop_det.sort_values('index')
# Out:
#       Company            TypeName Inches  \
# index
# 0       Apple           Ultrabook   13.3
# 1       Apple           Ultrabook   13.3
# 2          HP            Notebook   15.6
# 3       Apple           Ultrabook   15.4
# 4       Apple           Ultrabook   13.3
# ...       ...                 ...    ...
# 1298   Lenovo  2 in 1 Convertible     14
# 1299   Lenovo  2 in 1 Convertible   13.3
# 1300   Lenovo            Notebook     14
# 1301       HP            Notebook   15.6
# 1302     Asus            Notebook   15.6
#
#                                  ScreenResolution  \
# index
# 0              IPS Panel Retina Display 2560x1600
# 1                                        1440x900
# 2                               Full HD 1920x1080
# 3              IPS Panel Retina Display 2880x1800
# 4              IPS Panel Retina Display 2560x1600
# ...                                           ...
# 1298    IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
laptop=laptop_det[laptop_det['OpSys']=='No OS'].sort_values('index').index
laptop
# Out:
# Int64Index([   2,   10,   11,   18,   22,   62,   76,  122,  136,  138,  142,
#              172,  184,  187,  192,  193,  205,  212,  213,  216,  242,  261,
#              279,  289,  303,  305,  356,  364,  367,  381,  463,  509,  514,
#              527,  547,  594,  627,  643,  654,  704,  725,  752,  783,  850,
#              859,  863,  871,  932,  947,  992, 1056, 1061, 1091, 1128, 1150,
#             1152, 1164, 1173, 1174, 1196, 1201, 1217, 1248],
#            dtype='int64', name='index')

# %%
laptop_details=laptop_det.drop(laptop).sort_values('index')

# %%
def convert(price):
    return int(price)
laptop_details['Price']=laptop_details['Price'].apply(convert)

# %%
laptop_details.shape
# Out:
# (1210, 11)

# %%
laptop=laptop_details[laptop_details['OpSys']=='Mac OS X'].index
laptop
# Out:
# Int64Index([6, 26, 34, 794, 1069, 1193, 1210, 1234], dtype='int64', name='index')

# %%
laptop_details=laptop_details.drop(laptop)
laptop_details.shape
# Out:
# (1202, 11)

# %%
laptop_details['Inches']=laptop_details['Inches'].astype('category')

# %%
laptop_details=laptop_details.groupby('Company')

# %%
laptop_details.get_group('Dell').shape
# Out:
# (287, 11)

# %%
laptop_details.get_group('Dell').drop_duplicates(inplace=True)
# Out:
# C:\Users\91705\AppData\Local\Temp\ipykernel_9280\2390797154.py:1: SettingWithCopyWarning:
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
#
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   laptop_details.get_group('Dell').drop_duplicates(inplace=True)

# %%
laptop_details.get_group('Lenovo').shape
# Out:
# (245, 11)

# %%
laptop_details.get_group('Lenovo').drop_duplicates(inplace=True)
# Out:
# C:\Users\91705\AppData\Local\Temp\ipykernel_9280\901780976.py:1: SettingWithCopyWarning:
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
#
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   laptop_details.get_group('Lenovo').drop_duplicates(inplace=True)

# %%
laptop_details.get_group('HP').shape
# Out:
# (255, 11)

# %%
laptop_details.get_group('HP').drop_duplicates(inplace=True)
# Out:
# C:\Users\91705\AppData\Local\Temp\ipykernel_9280\970321158.py:1: SettingWithCopyWarning:
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
#
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   laptop_details.get_group('HP').drop_duplicates(inplace=True)

# %%
laptop_details.get_group('Asus').shape
# Out:
# (152, 11)

# %%
laptop_details.get_group('Asus').drop_duplicates(inplace=True)
# Out:
# C:\Users\91705\AppData\Local\Temp\ipykernel_9280\833203940.py:1: SettingWithCopyWarning:
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
#
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   laptop_details.get_group('Asus').drop_duplicates(inplace=True)

# %%
laptop_details.get_group('Acer').shape
# Out:
# (103, 11)

# %%
laptop_details.get_group('Acer').drop_duplicates(inplace=True)
# Out:
# C:\Users\91705\AppData\Local\Temp\ipykernel_9280\3336453905.py:1: SettingWithCopyWarning:
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
#
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   laptop_details.get_group('Acer').drop_duplicates(inplace=True)

# %%
laptop_details1=laptop_details.get_group('Dell')
laptop_details2=laptop_details.get_group('Lenovo')
laptop_details3=laptop_details.get_group('Acer')
laptop_details4=laptop_details.get_group('Asus')
laptop_details5=laptop_details.get_group('Apple')
laptop_details6=laptop_details.get_group('Chuwi')
laptop_details7=laptop_details.get_group('MSI')
laptop_details8=laptop_details.get_group('Microsoft')
laptop_details9=laptop_details.get_group('Toshiba')
laptop_details10=laptop_details.get_group('Huawei')
laptop_details11=laptop_details.get_group('Xiaomi')
laptop_details12=laptop_details.get_group('Vero')
laptop_details13=laptop_details.get_group('Razer')
laptop_details14=laptop_details.get_group('Mediacom')
laptop_details15=laptop_details.get_group('Samsung')
laptop_details16=laptop_details.get_group('Google')
laptop_details17=laptop_details.get_group('Fujitsu')
laptop_details18=laptop_details.get_group('LG')

# %%
laptop_cleaned_data=pd.concat([laptop_details1,laptop_details2,laptop_details3,laptop_details4,laptop_details5,laptop_details6,laptop_details7,laptop_details8,laptop_details9,laptop_details10,laptop_details11,laptop_details12,laptop_details13,laptop_details14,laptop_details15,laptop_details16,laptop_details17,laptop_details18])

# %%
laptop_cleaned_data.sort_values('Company')
# Out:
#       Company   TypeName Inches             ScreenResolution  \
# index
# 290      Acer   Notebook   15.6                     1366x768
# 888      Acer    Netbook   11.6           IPS Panel 1366x768
# 868      Acer   Notebook     14  IPS Panel Full HD 1920x1080
# 829      Acer   Notebook     14  IPS Panel Full HD 1920x1080
# 828      Acer    Netbook   11.6           IPS Panel 1366x768
# ...       ...        ...    ...                          ...
# 1120     Vero   Notebook   13.3            Full HD 1920x1080
# 191      Vero   Notebook     14  IPS Panel Full HD 1920x1080
# 1041     Vero   Notebook     14                     1366x768
# 791      Vero   Notebook     14                    1920x1080
# 877    Xiaomi  Ultrabook   13.3  IPS Panel Full HD 1920x1080
#
#                                         Cpu  Ram              Memory  \
# index
# 290    Intel Celeron Dual Core 3205U 1.5GHz  2GB            16GB SSD
# 888    Intel Celeron Dual Core N3060 1.6GHz  4GB  32GB Flash Storage
# ...

# %%
laptop_cleaned_data=laptop_cleaned_data.reset_index()

# %%
laptop_cleaned_data.duplicated().sum()
# Out:
# 0

# %%
laptop_cleaned_data['Weight']=laptop_cleaned_data['Weight'].str.replace('kg',' ')

# %%
laptop_cleaned_data.rename(columns={'Weight':'Weight(kg)'})
# Out:
#      index  Company            TypeName Inches  \
# 0       13     Dell            Notebook   15.6
# 1       16     Dell            Notebook   15.6
# 2       19     Dell           Ultrabook   13.3
# 3       23     Dell  2 in 1 Convertible   13.3
# 4       25     Dell            Notebook   15.6
# ..     ...      ...                 ...    ...
# 942    623  Fujitsu            Notebook   15.6
# 943    983  Fujitsu            Notebook   15.6
# 944    678       LG           Ultrabook   15.6
# 945    905       LG           Ultrabook   15.6
# 946    909       LG           Ultrabook     14
#
#                               ScreenResolution                         Cpu  \
# 0                            Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 1                            Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 2    IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
# 3              Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
# ...

# %%
laptop_cleaned_data['ScreenResolution']
# Out:
# 0                              Full HD 1920x1080
# 1                              Full HD 1920x1080
# 2      IPS Panel Full HD / Touchscreen 1920x1080
# 3                Full HD / Touchscreen 1920x1080
# 4                                       1366x768
#                          ...
# 942                                     1366x768
# 943                                     1366x768
# 944                  IPS Panel Full HD 1920x1080
# 945    IPS Panel Full HD / Touchscreen 1920x1080
# 946    IPS Panel Full HD / Touchscreen 1920x1080
# Name: ScreenResolution, Length: 947, dtype: object

# %%
import pandas as pd
import re

# Assuming you have a DataFrame called 'df' with a 'ScreenResolution' column
laptop_cleaned_data['ScreenResolution'].str.extractall(r'(\bFull HD\b|\b\d+x\d+\b)').unstack()
# Out:
#               0
# match         0          1
# 0       Full HD  1920x1080
# 1       Full HD  1920x1080
# 2       Full HD  1920x1080
# 3       Full HD  1920x1080
# 4      1366x768        NaN
# ..          ...        ...
# 942    1366x768        NaN
# 943    1366x768        NaN
# 944     Full HD  1920x1080
# 945     Full HD  1920x1080
# 946     Full HD  1920x1080
#
# [947 rows x 2 columns]

# %%
laptop_cleaned_data
# Out:
#      index  Company            TypeName Inches  \
# 0       13     Dell            Notebook   15.6
# 1       16     Dell            Notebook   15.6
# 2       19     Dell           Ultrabook   13.3
# 3       23     Dell  2 in 1 Convertible   13.3
# 4       25     Dell            Notebook   15.6
# ..     ...      ...                 ...    ...
# 942    623  Fujitsu            Notebook   15.6
# 943    983  Fujitsu            Notebook   15.6
# 944    678       LG           Ultrabook   15.6
# 945    905       LG           Ultrabook   15.6
# 946    909       LG           Ultrabook     14
#
#                               ScreenResolution                         Cpu  \
# 0                            Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 1                            Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 2    IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
# 3              Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
# ...

# %%
laptop_cleaned_data=laptop_cleaned_data.set_index('index').sort_values('index')

# %%
laptop_cleaned_data
# Out:
#       Company            TypeName Inches  \
# index
# 0       Apple           Ultrabook   13.3
# 1       Apple           Ultrabook   13.3
# 3       Apple           Ultrabook   15.4
# 4       Apple           Ultrabook   13.3
# 5        Acer            Notebook   15.6
# ...       ...                 ...    ...
# 1297     Asus            Notebook   15.6
# 1298   Lenovo  2 in 1 Convertible     14
# 1299   Lenovo  2 in 1 Convertible   13.3
# 1300   Lenovo            Notebook     14
# 1302     Asus            Notebook   15.6
#
#                                  ScreenResolution  \
# index
# 0              IPS Panel Retina Display 2560x1600
# 1                                        1440x900
# 3              IPS Panel Retina Display 2880x1800
# 4              IPS Panel Retina Display 2560x1600
# 5                                        1366x768
# ...                                           ...
# 1297                                     1366x768
# ...

# %%
laptop=pd.read_csv('laptopData.csv')
laptop
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
laptop_cleaned_data.sort_values('Company',ascending=True,inplace=True)

# %%
with pd.ExcelWriter('Uncleaned and Cleaned_laptop_data.xlsx') as writer:
    laptop.to_excel(writer,sheet_name='Uncleaned_laptop_data')
    laptop_cleaned_data.to_excel(writer,sheet_name='Cleaned_laptop_data')

# %%
# Out:
#                    TypeName Inches  \
# Company
# Apple             Ultrabook   13.3
# Apple             Ultrabook   13.3
# Apple             Ultrabook   15.4
# Apple             Ultrabook   13.3
# Acer               Notebook   15.6
# ...                     ...    ...
# Asus               Notebook   15.6
# Lenovo   2 in 1 Convertible     14
# Lenovo   2 in 1 Convertible   13.3
# Lenovo             Notebook     14
# Asus               Notebook   15.6
#
#                                    ScreenResolution  \
# Company
# Apple            IPS Panel Retina Display 2560x1600
# Apple                                      1440x900
# Apple            IPS Panel Retina Display 2880x1800
# Apple            IPS Panel Retina Display 2560x1600
# Acer                                       1366x768
# ...                                             ...
# Asus                                       1366x768
# Lenovo    IPS Panel Full HD / Touchscreen 1920x1080
# ...
